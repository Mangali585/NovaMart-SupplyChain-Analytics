# %%
pip install sqlalchemy pymysql
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\mangali\appdata\local\programs\python\python313\lib\site-packages (2.0.51)
# Requirement already satisfied: pymysql in c:\users\mangali\appdata\local\programs\python\python313\lib\site-packages (1.2.0)
# Requirement already satisfied: greenlet>=1 in c:\users\mangali\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (3.5.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\mangali\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

# %%
username = "root"

password = "Mang@1112"

host = "localhost"

database = "novamart_supplychain"

# %%
engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}/{database}"
)

# %%
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

connection_url = URL.create(
    drivername="mysql+pymysql",
    username="root",
    password="Mang@1112",
    host="localhost",
    database="novamart_supplychain"
)

engine = create_engine(connection_url)

try:
    with engine.connect():
        print("✅ Connection Successful!")
except Exception as e:
    print(e)
# Out:
# ✅ Connection Successful!

# %%
df.to_sql(
    "datacosupplychain_clean",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 180519
